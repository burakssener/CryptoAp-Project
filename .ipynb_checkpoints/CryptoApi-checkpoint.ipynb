# %%
#1-CoinMarketCap opening Crypto API section

#Creating anonymous account for privacy digareyes651@uma3.be name= digareyes651

# Looking for Apı Documentation

# %%
# Aligning API Key and API domain

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'cfba7043-c9d1-4f21-93b0-ec95fa82c1b6',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-07-14T08:19:07.532Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 10200}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10342, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19428931, 'total_supply': 19428931, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-14T08:17:00.000Z', 'quote': {'USD': {'price': 31235.02872120046, 'volume_24h': 26329405159.10631, 'volume_change_24h': 83.354, 'percent_change_1h': -0.21865644, 'percent_change_24h': 2.8430439, 'percent_change_7d': 3.90395807, 'percent_change_30d': 20.58661237, 'percent_change_60d': 13.94633304, 'percent_change_90d': 2.60250597, 'market_cap': 606863217807.2219, 'market_cap_dominance': 48.5276, 'fully_diluted_market_cap': 655935603145.21, 'tvl': None, 'last_updated': '2023-07-14T08:17:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7119, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120204712.07716507, 'total_supply': 120204712.07716507, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-14T08:17:00.000Z', 'quote': {'USD': {'price': 1998.8939149901596, 'volume_24h': 12941041615.694214, 'volume_change_24h': 115.912, 'percent_change_1h': -0.37323859, 'percent_change_24h': 6.79908593, 'percent_change_7d': 7.45266759, 'percent_change_30d': 14.73520248, 'percent_change_60d': 9.33862038, 'percent_change_90d': -4.68744655, 'market_cap': 240276467524.1894, 'market_cap_dominance': 19.2136, 'fully_diluted_market_cap': 240276467524.19, 'tvl': None, 'last_updated': '2023-07-14T08:17:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 56935, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 83434088922.61197, 'total_supply': 86730981418.02774, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', ' ...

# %%
#fixing data rate exceeded issue with anaconda prompt to increase data limit
#with Jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10 
#Copy the link from anaconda prompt otherwise, isnt working

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.json_normalize(data["status"])
#pd.set_option("display.max_columns", None)
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2023-07-14T08:19:07.532Z           0          None       18             1
#
#   notice  total_count
# 0   None        10200

# %%
pd.json_normalize(data["data"])
# Out:
#       id          name symbol          slug  num_market_pairs  \
# 0      1       Bitcoin    BTC       bitcoin             10342
# 1   1027      Ethereum    ETH      ethereum              7119
# 2    825        Tether   USDT        tether             56935
# 3     52           XRP    XRP           xrp               990
# 4   1839           BNB    BNB           bnb              1504
# 5   3408      USD Coin   USDC      usd-coin             13306
# 6   2010       Cardano    ADA       cardano               868
# 7   5426        Solana    SOL        solana               486
# 8     74      Dogecoin   DOGE      dogecoin               743
# 9   3890       Polygon  MATIC       polygon               773
# 10     2      Litecoin    LTC      litecoin               946
# 11  1958          TRON    TRX          tron               788
# 12  6636      Polkadot    DOT  polkadot-new               532
# 13  1831  Bitcoin Cash    BCH  bitcoin-cash               729
# 14  5805     Avalanche   AVAX     avalanche               465
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2020-04-10T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2019-04-28T00:00:00.000Z
# 10  2013-04-28T00:00:00.000Z
# 11  2017-09-13T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2017-07-23T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 10        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 11  [media, payments, tron-ecosystem, sec-security...           NaN
# 12  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 13  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 14  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap  \
# 0         1.942893e+07  1.942893e+07  ...          6.068632e+11
# 1         1.202047e+08  1.202047e+08  ...          2.402765e+11
# 2         8.343409e+10  8.673098e+10  ...          8.347059e+10
# 3         5.254409e+10  9.998862e+10  ...          4.106111e+10
# 4         1.558491e+08  1.558491e+08  ...          4.009797e+10
# 5         2.737944e+10  2.737944e+10  ...          2.737876e+10
# 6         3.497653e+10  3.596797e+10  ...          1.233607e+10
# 7         4.029028e+08  5.524422e+08  ...          1.158186e+10
# 8         1.401667e+11  1.401667e+11  ...          9.865447e+09
# 9         9.319469e+09  1.000000e+10  ...          7.989219e+09
# 10        7.335830e+07  8.400000e+07  ...          7.435424e+09
# 11        8.979580e+10  8.979593e+10  ...          7.365382e+09
# 12        1.210018e+09  1.333997e+09  ...          6.758338e+09
# 13        1.944834e+07  1.944834e+07  ...          5.334744e+09
# 14        3.458450e+08  4.325645e+08  ...          5.332222e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          48.5276                        6.559356e+11
# 1                          19.2136                        2.402765e+11
# 2                           6.6729                        8.676893e+10
# 3                           3.2834                        7.814602e+10
# 4                           3.2055                        4.009797e+10
# 5                           2.1893                        2.737876e+10
# 6                           0.9863                        1.587131e+10
# 7                           0.9261                        1.588053e+10
# 8                           0.7886                        9.865447e+09
# 9                           0.6389                        8.572612e+09
# 10                          0.5944                        8.514042e+09
# 11                          0.5888                        7.365393e+09
# 12                          0.5403                        7.450800e+09
# 13                          0.4265                        5.760368e+09
# 14                          0.4262                        1.110093e+10
#
#     quote.USD.tvl    quote.USD.last_updated platform.id platform.name  \
# 0            None  2023-07-14T08:17:00.000Z         NaN           NaN
# 1            None  2023-07-14T08:17:00.000Z         NaN           NaN
# 2            None  2023-07-14T08:17:00.000Z      1027.0      Ethereum
# 3            None  2023-07-14T08:17:00.000Z         NaN           NaN
# 4            None  2023-07-14T08:17:00.000Z         NaN           NaN
# 5            None  2023-07-14T08:17:00.000Z      1027.0      Ethereum
# 6            None  2023-07-14T08:17:00.000Z         NaN           NaN
# 7            None  2023-07-14T08:17:00.000Z         NaN           NaN
# 8            None  2023-07-14T08:17:00.000Z         NaN           NaN
# 9            None  2023-07-14T08:17:00.000Z         NaN           NaN
# 10           None  2023-07-14T08:17:00.000Z         NaN           NaN
# 11           None  2023-07-14T08:17:00.000Z         NaN           NaN
# 12           None  2023-07-14T08:17:00.000Z         NaN           NaN
# 13           None  2023-07-14T08:17:00.000Z         NaN           NaN
# 14           None  2023-07-14T08:17:00.000Z         NaN           NaN
#
#     platform.symbol  platform.slug                      platform.token_address
# 0               NaN            NaN                                         NaN
# 1               NaN            NaN                                         NaN
# 2               ETH       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3               NaN            NaN                                         NaN
# 4               NaN            NaN                                         NaN
# 5               ETH       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6               NaN            NaN                                         NaN
# 7               NaN            NaN                                         NaN
# 8               NaN            NaN                                         NaN
# 9               NaN            NaN                                         NaN
# 10              NaN            NaN                                         NaN
# 11              NaN            NaN                                         NaN
# 12              NaN            NaN                                         NaN
# 13              NaN            NaN                                         NaN
# 14              NaN            NaN                                         NaN
#
# [15 rows x 36 columns]

# %%
df = pd.json_normalize(data["data"])
df["timestamp"] = pd.to_datetime("now")
df
# Out:
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\2582439822.py:2: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df["timestamp"] = pd.to_datetime("now")
#       id          name symbol          slug  num_market_pairs  \
# 0      1       Bitcoin    BTC       bitcoin             10342
# 1   1027      Ethereum    ETH      ethereum              7119
# 2    825        Tether   USDT        tether             56935
# 3     52           XRP    XRP           xrp               990
# 4   1839           BNB    BNB           bnb              1504
# 5   3408      USD Coin   USDC      usd-coin             13306
# 6   2010       Cardano    ADA       cardano               868
# 7   5426        Solana    SOL        solana               486
# 8     74      Dogecoin   DOGE      dogecoin               743
# 9   3890       Polygon  MATIC       polygon               773
# 10     2      Litecoin    LTC      litecoin               946
# 11  1958          TRON    TRX          tron               788
# 12  6636      Polkadot    DOT  polkadot-new               532
# 13  1831  Bitcoin Cash    BCH  bitcoin-cash               729
# 14  5805     Avalanche   AVAX     avalanche               465
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2020-04-10T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2019-04-28T00:00:00.000Z
# 10  2013-04-28T00:00:00.000Z
# 11  2017-09-13T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2017-07-23T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 10        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 11  [media, payments, tron-ecosystem, sec-security...           NaN
# 12  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 13  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 14  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.942893e+07  1.942893e+07  ...                         48.5276
# 1         1.202047e+08  1.202047e+08  ...                         19.2136
# 2         8.343409e+10  8.673098e+10  ...                          6.6729
# 3         5.254409e+10  9.998862e+10  ...                          3.2834
# 4         1.558491e+08  1.558491e+08  ...                          3.2055
# 5         2.737944e+10  2.737944e+10  ...                          2.1893
# 6         3.497653e+10  3.596797e+10  ...                          0.9863
# 7         4.029028e+08  5.524422e+08  ...                          0.9261
# 8         1.401667e+11  1.401667e+11  ...                          0.7886
# 9         9.319469e+09  1.000000e+10  ...                          0.6389
# 10        7.335830e+07  8.400000e+07  ...                          0.5944
# 11        8.979580e+10  8.979593e+10  ...                          0.5888
# 12        1.210018e+09  1.333997e+09  ...                          0.5403
# 13        1.944834e+07  1.944834e+07  ...                          0.4265
# 14        3.458450e+08  4.325645e+08  ...                          0.4262
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         6.559356e+11           None
# 1                         2.402765e+11           None
# 2                         8.676893e+10           None
# 3                         7.814602e+10           None
# 4                         4.009797e+10           None
# 5                         2.737876e+10           None
# 6                         1.587131e+10           None
# 7                         1.588053e+10           None
# 8                         9.865447e+09           None
# 9                         8.572612e+09           None
# 10                        8.514042e+09           None
# 11                        7.365393e+09           None
# 12                        7.450800e+09           None
# 13                        5.760368e+09           None
# 14                        1.110093e+10           None
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 1   2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 2   2023-07-14T08:17:00.000Z       1027.0      Ethereum             ETH
# 3   2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 4   2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 5   2023-07-14T08:17:00.000Z       1027.0      Ethereum             ETH
# 6   2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 7   2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 8   2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 9   2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 10  2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 11  2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 12  2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 13  2023-07-14T08:17:00.000Z          NaN           NaN             NaN
# 14  2023-07-14T08:17:00.000Z          NaN           NaN             NaN
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# 5        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6             NaN                                         NaN
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
# 10            NaN                                         NaN
# 11            NaN                                         NaN
# 12            NaN                                         NaN
# 13            NaN                                         NaN
# 14            NaN                                         NaN
#
#                     timestamp
# 0  2023-07-14 08:19:08.682197
# 1  2023-07-14 08:19:08.682197
# 2  2023-07-14 08:19:08.682197
# 3  2023-07-14 08:19:08.682197
# 4  2023-07-14 08:19:08.682197
# 5  2023-07-14 08:19:08.682197
# 6  2023-07-14 08:19:08.682197
# 7  2023-07-14 08:19:08.682197
# 8  2023-07-14 08:19:08.682197
# 9  2023-07-14 08:19:08.682197
# 10 2023-07-14 08:19:08.682197
# 11 2023-07-14 08:19:08.682197
# 12 2023-07-14 08:19:08.682197
# 13 2023-07-14 08:19:08.682197
# 14 2023-07-14 08:19:08.682197
#
# [15 rows x 37 columns]

# %%
def api_runner():
    global df
    from requests import Request, Session
    from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
    import json
    import pandas as pd

    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'cfba7043-c9d1-4f21-93b0-ec95fa82c1b6',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    df2 = pd.json_normalize(data["data"])
    df2["timestamp"] = pd.to_datetime("now")
    df = df.append(df2)

# %%
import os
from time import time
from time import sleep

for i in range(20):
    api_runner()
    print("Data is pulled successfully")
    sleep(20)
exit()
# Out:
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_6208\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       6     api_runner()
#       7     print("Data is pulled successfully")
# ----> 8     sleep(20)
#       9 exit()
#
# KeyboardInterrupt:

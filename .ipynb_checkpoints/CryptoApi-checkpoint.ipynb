# %%
#1-CoinMarketCap opening Crypto API section

#Creating anonymous account for privacy digareyes651@uma3.be name= digareyes651

# Looking for Apı Documentation

# %%
# Aligning API Key and API domain

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'cfba7043-c9d1-4f21-93b0-ec95fa82c1b6',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-07-14T18:02:31.241Z', 'error_code': 0, 'error_message': None, 'elapsed': 30, 'credit_count': 1, 'notice': None, 'total_count': 10203}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10342, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19429231, 'total_supply': 19429231, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-14T18:01:00.000Z', 'quote': {'USD': {'price': 30655.68764649669, 'volume_24h': 22749099652.475822, 'volume_change_24h': 30.6424, 'percent_change_1h': -1.78031516, 'percent_change_24h': -1.40107398, 'percent_change_7d': 1.3567851, 'percent_change_30d': 17.90024993, 'percent_change_60d': 11.39441937, 'percent_change_90d': 1.27054306, 'market_cap': 595616436747.6306, 'market_cap_dominance': 48.2988, 'fully_diluted_market_cap': 643769440576.43, 'tvl': None, 'last_updated': '2023-07-14T18:01:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7121, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120204712.07716507, 'total_supply': 120204712.07716507, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-14T18:01:00.000Z', 'quote': {'USD': {'price': 1960.4490818304205, 'volume_24h': 10663713209.186228, 'volume_change_24h': 18.0296, 'percent_change_1h': -1.52016394, 'percent_change_24h': -1.53512532, 'percent_change_7d': 4.96406078, 'percent_change_30d': 12.62978428, 'percent_change_60d': 6.84829497, 'percent_change_90d': -6.29042151, 'market_cap': 235655217423.36832, 'market_cap_dominance': 19.1791, 'fully_diluted_market_cap': 235655217423.37, 'tvl': None, 'last_updated': '2023-07-14T18:01:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 56948, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 83434088922.61197, 'total_supply': 86730981418.02774, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET ...

# %%
#fixing data rate exceeded issue with anaconda prompt to increase data limit
#with Jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10 
#Copy the link from anaconda prompt otherwise, isnt working

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.json_normalize(data["status"])
#pd.set_option("display.max_columns", None)
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2023-07-14T18:02:31.241Z           0          None       30             1
#
#   notice  total_count
# 0   None        10203

# %%
pd.json_normalize(data["data"])
# Out:
#       id          name symbol          slug  num_market_pairs  \
# 0      1       Bitcoin    BTC       bitcoin             10342
# 1   1027      Ethereum    ETH      ethereum              7121
# 2    825        Tether   USDT        tether             56948
# 3   1839           BNB    BNB           bnb              1504
# 4     52           XRP    XRP           xrp               992
# 5   3408      USD Coin   USDC      usd-coin             13311
# 6   2010       Cardano    ADA       cardano               870
# 7   5426        Solana    SOL        solana               486
# 8     74      Dogecoin   DOGE      dogecoin               743
# 9   3890       Polygon  MATIC       polygon               774
# 10  1958          TRON    TRX          tron               788
# 11     2      Litecoin    LTC      litecoin               946
# 12  6636      Polkadot    DOT  polkadot-new               532
# 13  5805     Avalanche   AVAX     avalanche               465
# 14  1831  Bitcoin Cash    BCH  bitcoin-cash               729
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2020-04-10T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2019-04-28T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2020-07-13T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 10  [media, payments, tron-ecosystem, sec-security...           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 13  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap  \
# 0         1.942923e+07  1.942923e+07  ...          5.956164e+11
# 1         1.202047e+08  1.202047e+08  ...          2.356552e+11
# 2         8.343409e+10  8.673098e+10  ...          8.347950e+10
# 3         1.558490e+08  1.558490e+08  ...          3.902413e+10
# 4         5.254409e+10  9.998862e+10  ...          3.726229e+10
# 5         2.728069e+10  2.728069e+10  ...          2.728638e+10
# 6         3.497652e+10  3.596797e+10  ...          1.160488e+10
# 7         4.029024e+08  5.524418e+08  ...          1.094379e+10
# 8         1.401710e+11  1.401710e+11  ...          9.796906e+09
# 9         9.319469e+09  1.000000e+10  ...          7.605363e+09
# 10        8.978944e+10  8.978957e+10  ...          7.205228e+09
# 11        7.336105e+07  8.400000e+07  ...          7.145065e+09
# 12        1.246677e+09  1.334156e+09  ...          6.841046e+09
# 13        3.458462e+08  4.325657e+08  ...          5.201201e+09
# 14        1.944862e+07  1.944862e+07  ...          5.160852e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          48.2988                        6.437694e+11
# 1                          19.1791                        2.356552e+11
# 2                           6.7868                        8.677818e+10
# 3                           3.1760                        3.902413e+10
# 4                           3.0216                        7.091623e+10
# 5                           2.2127                        2.728638e+10
# 6                           0.9422                        1.493057e+10
# 7                           0.8907                        1.500564e+10
# 8                           0.7940                        9.796906e+09
# 9                           0.6190                        8.160725e+09
# 10                          0.5858                        7.205238e+09
# 11                          0.5791                        8.181255e+09
# 12                          0.5568                        7.321083e+09
# 13                          0.4215                        1.082812e+10
# 14                          0.4196                        5.572522e+09
#
#     quote.USD.tvl    quote.USD.last_updated platform.id platform.name  \
# 0            None  2023-07-14T18:01:00.000Z         NaN           NaN
# 1            None  2023-07-14T18:01:00.000Z         NaN           NaN
# 2            None  2023-07-14T18:01:00.000Z      1027.0      Ethereum
# 3            None  2023-07-14T18:01:00.000Z         NaN           NaN
# 4            None  2023-07-14T18:01:00.000Z         NaN           NaN
# 5            None  2023-07-14T18:01:00.000Z      1027.0      Ethereum
# 6            None  2023-07-14T18:01:00.000Z         NaN           NaN
# 7            None  2023-07-14T18:01:00.000Z         NaN           NaN
# 8            None  2023-07-14T18:01:00.000Z         NaN           NaN
# 9            None  2023-07-14T18:01:00.000Z         NaN           NaN
# 10           None  2023-07-14T18:01:00.000Z         NaN           NaN
# 11           None  2023-07-14T18:01:00.000Z         NaN           NaN
# 12           None  2023-07-14T18:01:00.000Z         NaN           NaN
# 13           None  2023-07-14T18:01:00.000Z         NaN           NaN
# 14           None  2023-07-14T18:01:00.000Z         NaN           NaN
#
#     platform.symbol  platform.slug                      platform.token_address
# 0               NaN            NaN                                         NaN
# 1               NaN            NaN                                         NaN
# 2               ETH       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3               NaN            NaN                                         NaN
# 4               NaN            NaN                                         NaN
# 5               ETH       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6               NaN            NaN                                         NaN
# 7               NaN            NaN                                         NaN
# 8               NaN            NaN                                         NaN
# 9               NaN            NaN                                         NaN
# 10              NaN            NaN                                         NaN
# 11              NaN            NaN                                         NaN
# 12              NaN            NaN                                         NaN
# 13              NaN            NaN                                         NaN
# 14              NaN            NaN                                         NaN
#
# [15 rows x 36 columns]

# %%
df = pd.json_normalize(data["data"])
df["timestamp"] = pd.to_datetime("now")
df
# Out:
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\2582439822.py:2: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df["timestamp"] = pd.to_datetime("now")
#       id          name symbol          slug  num_market_pairs  \
# 0      1       Bitcoin    BTC       bitcoin             10342
# 1   1027      Ethereum    ETH      ethereum              7121
# 2    825        Tether   USDT        tether             56948
# 3   1839           BNB    BNB           bnb              1504
# 4     52           XRP    XRP           xrp               992
# 5   3408      USD Coin   USDC      usd-coin             13311
# 6   2010       Cardano    ADA       cardano               870
# 7   5426        Solana    SOL        solana               486
# 8     74      Dogecoin   DOGE      dogecoin               743
# 9   3890       Polygon  MATIC       polygon               774
# 10  1958          TRON    TRX          tron               788
# 11     2      Litecoin    LTC      litecoin               946
# 12  6636      Polkadot    DOT  polkadot-new               532
# 13  5805     Avalanche   AVAX     avalanche               465
# 14  1831  Bitcoin Cash    BCH  bitcoin-cash               729
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2020-04-10T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2019-04-28T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2020-07-13T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 10  [media, payments, tron-ecosystem, sec-security...           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 13  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.942923e+07  1.942923e+07  ...                         48.2988
# 1         1.202047e+08  1.202047e+08  ...                         19.1791
# 2         8.343409e+10  8.673098e+10  ...                          6.7868
# 3         1.558490e+08  1.558490e+08  ...                          3.1760
# 4         5.254409e+10  9.998862e+10  ...                          3.0216
# 5         2.728069e+10  2.728069e+10  ...                          2.2127
# 6         3.497652e+10  3.596797e+10  ...                          0.9422
# 7         4.029024e+08  5.524418e+08  ...                          0.8907
# 8         1.401710e+11  1.401710e+11  ...                          0.7940
# 9         9.319469e+09  1.000000e+10  ...                          0.6190
# 10        8.978944e+10  8.978957e+10  ...                          0.5858
# 11        7.336105e+07  8.400000e+07  ...                          0.5791
# 12        1.246677e+09  1.334156e+09  ...                          0.5568
# 13        3.458462e+08  4.325657e+08  ...                          0.4215
# 14        1.944862e+07  1.944862e+07  ...                          0.4196
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         6.437694e+11           None
# 1                         2.356552e+11           None
# 2                         8.677818e+10           None
# 3                         3.902413e+10           None
# 4                         7.091623e+10           None
# 5                         2.728638e+10           None
# 6                         1.493057e+10           None
# 7                         1.500564e+10           None
# 8                         9.796906e+09           None
# 9                         8.160725e+09           None
# 10                        7.205238e+09           None
# 11                        8.181255e+09           None
# 12                        7.321083e+09           None
# 13                        1.082812e+10           None
# 14                        5.572522e+09           None
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 1   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 2   2023-07-14T18:01:00.000Z       1027.0      Ethereum             ETH
# 3   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 4   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 5   2023-07-14T18:01:00.000Z       1027.0      Ethereum             ETH
# 6   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 7   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 8   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 9   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 10  2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 11  2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 12  2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 13  2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 14  2023-07-14T18:01:00.000Z          NaN           NaN             NaN
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# 5        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6             NaN                                         NaN
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
# 10            NaN                                         NaN
# 11            NaN                                         NaN
# 12            NaN                                         NaN
# 13            NaN                                         NaN
# 14            NaN                                         NaN
#
#                     timestamp
# 0  2023-07-14 18:02:32.949689
# 1  2023-07-14 18:02:32.949689
# 2  2023-07-14 18:02:32.949689
# 3  2023-07-14 18:02:32.949689
# 4  2023-07-14 18:02:32.949689
# 5  2023-07-14 18:02:32.949689
# 6  2023-07-14 18:02:32.949689
# 7  2023-07-14 18:02:32.949689
# 8  2023-07-14 18:02:32.949689
# 9  2023-07-14 18:02:32.949689
# 10 2023-07-14 18:02:32.949689
# 11 2023-07-14 18:02:32.949689
# 12 2023-07-14 18:02:32.949689
# 13 2023-07-14 18:02:32.949689
# 14 2023-07-14 18:02:32.949689
#
# [15 rows x 37 columns]

# %%
def api_runner():
    global df
    from requests import Request, Session
    from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
    import json
    import pandas as pd

    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'cfba7043-c9d1-4f21-93b0-ec95fa82c1b6',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    df = pd.json_normalize(data["data"])
    df["timestamp"] = pd.to_datetime("now")
    df 
    
    if not os.path.isfile(r"C:\Users\burak\Desktop\GitCryptoApı\API.csv"):
        df.to_csv(r"C:\Users\burak\Desktop\GitCryptoApı\API.csv", header = "column_names")
    else:
        df.to_csv(r"C:\Users\burak\Desktop\GitCryptoApı\API.csv", mode="a", header = False)

# %%
import os
from time import time
from time import sleep

for i in range(20):
    api_runner()
    print("Data is pulled successfully")
    sleep(5)
exit()
# Out:
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:29: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2["timestamp"] = pd.to_datetime("now")
# C:\Users\burak\AppData\Local\Temp\ipykernel_12544\3428536295.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# Data is pulled successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       6     api_runner()
#       7     print("Data is pulled successfully")
# ----> 8     sleep(20)
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#       id          name symbol          slug  num_market_pairs  \
# 0      1       Bitcoin    BTC       bitcoin             10342
# 1   1027      Ethereum    ETH      ethereum              7121
# 2    825        Tether   USDT        tether             56948
# 3   1839           BNB    BNB           bnb              1504
# 4     52           XRP    XRP           xrp               992
# ..   ...           ...    ...           ...               ...
# 10  1958          TRON    TRX          tron               788
# 11     2      Litecoin    LTC      litecoin               946
# 12  6636      Polkadot    DOT  polkadot-new               532
# 13  5805     Avalanche   AVAX     avalanche               465
# 14  1831  Bitcoin Cash    BCH  bitcoin-cash               729
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# ..                       ...
# 10  2017-09-13T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2020-07-13T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# ..                                                ...           ...
# 10  [media, payments, tron-ecosystem, sec-security...           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 13  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.942923e+07  1.942923e+07  ...                         48.2988
# 1         1.202047e+08  1.202047e+08  ...                         19.1791
# 2         8.343409e+10  8.673098e+10  ...                          6.7868
# 3         1.558490e+08  1.558490e+08  ...                          3.1760
# 4         5.254409e+10  9.998862e+10  ...                          3.0216
# ..                 ...           ...  ...                             ...
# 10        8.978944e+10  8.978957e+10  ...                          0.5866
# 11        7.336105e+07  8.400000e+07  ...                          0.5826
# 12        1.246677e+09  1.334156e+09  ...                          0.5584
# 13        3.458462e+08  4.325657e+08  ...                          0.4256
# 14        1.944862e+07  1.944862e+07  ...                          0.4206
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         6.437694e+11           None
# 1                         2.356552e+11           None
# 2                         8.677818e+10           None
# 3                         3.902413e+10           None
# 4                         7.091623e+10           None
# ..                                 ...            ...
# 10                        7.208413e+09           None
# 11                        8.187345e+09           None
# 12                        7.342462e+09           None
# 13                        1.087448e+10           None
# 14                        5.580631e+09           None
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 1   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 2   2023-07-14T18:01:00.000Z       1027.0      Ethereum             ETH
# 3   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# 4   2023-07-14T18:01:00.000Z          NaN           NaN             NaN
# ..                       ...          ...           ...             ...
# 10  2023-07-14T18:05:00.000Z          NaN           NaN             NaN
# 11  2023-07-14T18:05:00.000Z          NaN           NaN             NaN
# 12  2023-07-14T18:05:00.000Z          NaN           NaN             NaN
# 13  2023-07-14T18:05:00.000Z          NaN           NaN             NaN
# 14  2023-07-14T18:05:00.000Z          NaN           NaN             NaN
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# ..            ...                                         ...
# 10            NaN                                         NaN
# 11            NaN                                         NaN
# 12            NaN                                         NaN
# 13            NaN                                         NaN
# 14            NaN                                         NaN
#
#                     timestamp
# 0  2023-07-14 18:02:32.949689
# 1  2023-07-14 18:02:32.949689
# 2  2023-07-14 18:02:32.949689
# 3  2023-07-14 18:02:32.949689
# 4  2023-07-14 18:02:32.949689
# ..                        ...
# 10 2023-07-14 18:06:58.015899
# 11 2023-07-14 18:06:58.015899
# 12 2023-07-14 18:06:58.015899
# 13 2023-07-14 18:06:58.015899
# 14 2023-07-14 18:06:58.015899
#
# [225 rows x 37 columns]
